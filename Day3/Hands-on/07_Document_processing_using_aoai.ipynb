# %% [markdown]
# # Document Processing
# Using Azure OpenAI service to extract key entities with OUT using Azure AI Document Intelligence service

# %% [markdown]
# ### 1. Install required libraries

# %%
# install Python PDF library
# %pip install PyPDF2

# %% [markdown]
# ### 2. Import helper libraries and load credentials from .env file

# %%
import os
from openai import AzureOpenAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### 3. Create AOAI client

# %%
# Create AOAI client using end point and key credentials
client = AzureOpenAI(
  azure_endpoint = os.getenv("OPENAI_API_ENDPOINT"), 
  api_key=os.getenv("OPENAI_API_KEY"),    
  api_version='2023-05-15',
)

# %% [markdown]
# ### 4. Setup PDF information
# Using sample PDF document from blob storage

# %%
import PyPDF2
import openai
import os
from urllib.request import urlopen
import urllib.request
import shutil
#from azure.storage.blob import ContainerClient, BlobServiceClient, BlockBlobService

# Replace with your OpenAI API key and model
my_ai_model = "gpt-4o"
pdf_file_url = os.getenv("BLOB_SAS_URL")
print(pdf_file_url)

with urlopen (pdf_file_url) as resp:
    print(resp.read())

local_file_name="sample-ukho-doc-process-using-aoai.pdf"
# Download the file from `url` and save it locally under `local_file_name`:
with urllib.request.urlopen(pdf_file_url) as response, open(local_file_name, 'wb') as out_file:
    shutil.copyfileobj(response, out_file)
# Out:
# https://ukhosampledocs.blob.core.windows.net/docs/Cleowent%20Agreement%20with%20Tidal%20Licence%20-%2003.01.2012.pdf?sp=r&st=2024-09-14T19:52:31Z&se=2024-09-15T03:52:31Z&spr=https&sv=2022-11-02&sr=b&sig=ylv4hPn8S9ocYICwj0P173Mw2hcJdIs6QW0KTdDGpqk%3D
# b'%PDF-1.7\r\n%\xb5\xb5\xb5\xb5\r\n1 0 obj\r\n<</Type/Catalog/Pages 2 0 R/Lang(en) /StructTreeRoot 50 0 R/MarkInfo<</Marked true>>/Metadata 720 0 R/ViewerPreferences 721 0 R>>\r\nendobj\r\n2 0 obj\r\n<</Type/Pages/Count 10/Kids[ 4 0 R 12 0 R 21 0 R 23 0 R 25 0 R 27 0 R 34 0 R 43 0 R 46 0 R 48 0 R] >>\r\nendobj\r\n3 0 obj\r\n<</MSIP_Label_f42aa342-8706-4288-bd11-ebb85995028c_SiteId(72f988bf-86f1-41af-91ab-2d7cd011db47) /MSIP_Label_f42aa342-8706-4288-bd11-ebb85995028c_Method(Privileged) /MSIP_Label_f42aa342-8706-4288-bd11-ebb85995028c_Enabled(True) /Title(AGREEMENT) /Author(Keith Packer) /Creator(\xfe\xff\x00M\x00i\x00c\x00r\x00o\x00s\x00o\x00f\x00t\x00\xae\x00 \x00W\x00o\x00r\x00d\x00 \x00f\x00o\x00r\x00 \x00M\x00i\x00c\x00r\x00o\x00s\x00o\x00f\x00t\x00 \x003\x006\x005) /CreationDate(D:20240822074312+01\'00\') /ModDate(D:20240822074312+01\'00\') /Producer(\xfe\xff\x00M\x00i\x00c\x00r\x00o\x00s\x00o\x00f\x00t\x00\xae\x00 \x00W\x00o\x00r\x00d\x00 \x00f\x00o\x00r\x00 \x00M\x00i\x00c\x00r\x00o\x00s\x00o\x00f\x00t\x00 \x003\x006\x005) >>\r\nendobj\r\n4 0 obj\r\n<</Type/Page/Parent 2 0 R/Resources<</Font<</F1 6 0 R/F2 10 0 R>>/ExtGState<</GS8 8 0 R/GS9 9 0 R>>/ProcSet[/PDF/Text/ImageB/ImageC/ImageI] >>/MediaBox[ 0 0 595.2 841.8] /Contents 5 0 R/Group<</Type/Group/S/Transparency/CS/DeviceRGB>>/Tabs/S/StructParents 0>>\r\nendobj\r\n5 0 obj\r\n<</Filter/FlateDecode/Length 854>>\r\nstream\r\nx\x9c\xb5\x98MO\xdb@\x10\x86\xef\x96\xfc\x1f\xf6hW\xcaz\xbfw-!\xa4|8\x1f-Ihb\x8a*\xc4!\x80I9\x10\xd3\xd4\xad\xd4\x7f\xdf\xd9@\x0f!\xb6\x886k.\xc4\xce\xc6\xf3\xcc\xecx\xde\xd7N\xba\xdb\xea\xe9qu_\xa1\xb3\xb3\xa4[U\xab\xfb\x1f\xc5\x03\xbaI\xf2\xf2\xe56\xc9\xff\xbe\x
x1bT{\x1a(`\x1217(/\x1a\xb8?\xd9)\x98\x05\xe8,\xc3\xb19l\xa9\xfeE6\xbf\xcef\'\x9a\xec\xfd\x80\x8c\xa7\x98\xa4M\x11O\x1c\xfd\xefB\tn\x0b\xde\x10j\xdc]\xf4\xe6W\xf6\xb9\xc2kPn_(4\x06\xed[\x95{\x95\xc3\xe9d\xb9\x041\x9c\xccO4\x7f\xfb\xe1\x05\x18Nzlyk\x9b\xcc\x8b\xa71u\x9d\xcf\x15\xf4\x9a[\xe7\xb7\xe0i\xfeC\x89\xdd w\x81\xf2b\x0c\xf6\xa1\xde\xdet\x82g\xd1\x1f\x16\xea\xc4>\x85GJ\xf8\x95\xd7PM\x85\xf2bV\xeaw\xcf\xbe\x90:n\xf7\xfe\x01\x08\xca\xc9q\r\nendstream\r\nendobj\r\n6 0 obj\r\n<</Type/Font/Subtype/TrueType/Name/F1/BaseFont/TimesNewRomanPSMT/Encoding/WinAnsiEncoding/FontDescriptor 7 0 R ...

# %% [markdown]
# ### 5. Read  PDF document

# %%
processed_text_list = []
# Open the PDF file in binary mode
with open(local_file_name, 'rb') as pdf_file:
    pdf_reader = PyPDF2.PdfReader(pdf_file)
    #print(pdf_reader)
    # Iterate through each page and extract text
    for page_num in range(len(pdf_reader.pages)):
        page = pdf_reader.pages[page_num]
        page_text = page.extract_text()
        processed_text_list.append(page_text)

# Combine all AI-processed text into a single string
combined_text = "\n".join(processed_text_list)

# %% [markdown]
# ### 6. Now format the message to send to GPT model

# %%
messages = [
        {
            "role": "system",
            "content": """You are a Assistant, a backend processor.
- User input is messy raw text extracted from a PDF page by PyPDF2.
- Answer with polite and positive sense.
"""
        },
        {
            "role": "user",
            "content": "Summarize the content:" + combined_text
        }
    ]

# %% [markdown]
# ### 7. Invoke GPT Model

# %%
response = client.chat.completions.create(
    model=my_ai_model, # model = "deployment_name".
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# The Agreement dated 15 November 2011, is between the United Kingdom Hydrographic Office (UKHO), on behalf of the Secretary of State for Defence, and Cleowent Harbour Commission (CHC). This non-exclusive Agreement ensures the exchange of hydrographic surveys, data, and related information.
#
# Key Points:
# 1. **Purpose and Exchange:**
#    - The UKHO and CHC will exchange marine data, surveys, navigational products, and related information.
#    - Defined terms and exchange details are included in Appendices.
#
# 2. **Usage and Intellectual Property:**
#    - UKHO can use and reproduce CHC’s material in its products and services, crediting CHC.
#    - License fees from UKHO’s use of CHC's data will be transferred to CHC annually.
#
# 3. **Licensing:**
#    - CHC grants UKHO the right to license its intellectual property to third parties.
#    - Both parties agree to protect each other's intellectual property rights.
#
# 4. **Liability and Implementation:**
#    - Liabilities rest with the supplying party unless modifications are made by the receiving party.
#    - The Agreement comes into effect on the date of the last signature and replaces the previous agreement from 26 September 2008.
#
# 5. **Confidentiality and Disputes:**
#    - Confidentiality must be maintained, and disputes are to be resolved through consultation.
#    - The Agreement can be terminated by either party with twelve months' notice.
#
# 6. **Miscellaneous:**
#    - English law governs the Agreement.
#    - Specific representatives from each party are designated as custodians of the Agreement.
#
# The Agreement facilitates mutual benefits in hydrographic data exchange, ensuring proper usage, acknowledgment, and protection of intellectual property rights, alongside clear liability and termination terms.

# %% [markdown]
# ### 8. Print the token usage

# %%
# print total token usage
print(response.usage)
# Out:
# CompletionUsage(completion_tokens=362, prompt_tokens=5066, total_tokens=5428)
