# %% [markdown]
# # 04. Azure AI Document Intelligence - Custom Model

# %% [markdown]
# > https://learn.microsoft.com/en-us/azure/ai-services/document-intelligence/overview?view=doc-intel-4.0.0

# %% [markdown]
# ## A. Create an AI Document Intelligence resource and set up environment to run notebook
#
# **_Prerequsite_:** <br>
#
# **AI Document Intelligence resource**: <br>
# To create a AI Document Intelligence resource in your Azure subscription:
# Please follow the steps as specified https://learn.microsoft.com/en-us/azure/ai-services/document-intelligence/create-document-intelligence-resource?view=doc-intel-4.0.0
#
#
# Get your newly created Document Intelligence service in the Azure portal and on the **Keys and Endpoint** page, copy the **Key1** and **Endpoint** values and paste them in the code cell below, replacing **YOUR_FORM_KEY** and **YOUR_FORM_ENDPOINT**.

# %% [markdown]
# **Environment: **
#
# 1. **AML workspace**: Please ensure you have Python 3.10 version or above ie select **Python 3.10 - SDK v2** as kernel in AML Notebook. <br>
# 2. **VS Code**: Please select Python **Python 3.10** above or try to set up virtual envi by following steps https://code.visualstudio.com/docs/python/environments
#
# Please skip this step if you are already done it

# %% [markdown]
# ## B. Install AI Doc Intelligence library

# %%
# install azure-ai-formrecognizer python library and restart the kernal after installation
# ignore this step is you have already installed azure-ai-formrecognizer python library
#%pip install azure-ai-formrecognizer --upgrade --user
# Out:
# Collecting azure-ai-formrecognizer
#   Using cached azure_ai_formrecognizer-3.3.2-py3-none-any.whl (300 kB)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.0 in /home/azureuser/.local/lib/python3.10/site-packages (from azure-ai-formrecognizer) (1.29.6)
# Requirement already satisfied: msrest>=0.6.21 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-formrecognizer) (0.7.1)
# Requirement already satisfied: azure-common~=1.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-formrecognizer) (1.1.28)
# Requirement already satisfied: typing-extensions>=4.0.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-formrecognizer) (4.6.3)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/azureuser/.local/lib/python3.10/site-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (4.2.0)
# Requirement already satisfied: requests>=2.21.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (2023.5.7)
# Requirement already satisfied: isodate>=0.6.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from anyio<5.0,>=3.0->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/azureuser/.local/lib/python3.10/site-packages (from anyio<5.0,>=3.0->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/azureuser/.local/lib/python3.10/site-packages (from anyio<5.0,>=3.0->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (3.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (1.26.16)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer) (3.2.2)
# Installing collected packages: azure-ai-formrecognizer
# Successfully installed azure-ai-formrecognizer-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## C. Build custom model
#
# - Please follow the steps to create custom model https://learn.microsoft.com/en-us/azure/ai-services/document-intelligence/how-to-guides/build-a-custom-model?view=doc-intel-4.0.0
# - Sample docs are available to build custom model at https://dev.azure.com/datasciencesquad/ai-bootcamp-2024/_git/week2-search-formrecognizer-app-agents?path=/Day2/AI-Doc-Intelligence-Sample-Files <br>
# - Upload the sample documents to train ie label the documents and use the one of the sample file to test the model <br>

# %% [markdown]
# ## D. Setting up AI Doc Intelligence endpoint, key and custom model id

# %%
# Import the os module for interacting with the operating system
import os
# Import for handling resource not found errors
from azure.core.exceptions import ResourceNotFoundError
# Import for authenticating with the Azure service
from azure.core.credentials import AzureKeyCredential
# Import for analysing forms
from azure.ai.formrecognizer import DocumentAnalysisClient, AnalyzeResult

# set `<your-endpoint>` and `<your-key>` variables with the values from the Azure portal
END_POINT = "https://xxxxxxxxxxxxxx.azure.com/"
END_POINT_KEY = "xxxxxxxxxxxxxxxxxxxxxxx"
# custom model id that you have created
CUSTOM_MODEL_ID = "xxxxxxxx"

# create form recognizer client
form_recognizer_client = DocumentAnalysisClient(END_POINT, AzureKeyCredential(END_POINT_KEY))

# %% [markdown]
# ## E. Extract the document insights using custom model

# %%
# sample document
# You can change the URL pointing to your sample custom docs but ensure you provide appropriate access
# sample documents available in the following page https://dev.azure.com/datasciencesquad/ai-bootcamp-2024/_git/week2-search-formrecognizer-app-agents?path=/Day2/AI-Doc-Intelligence-Sample-Files to train and create custom model
# make sure you enable at least read only access for the doc from your storage container account
sampleUrl = "https://xxxxxxxxxxxxxx.pdf"

poller = form_recognizer_client.begin_analyze_document_from_url(CUSTOM_MODEL_ID,sampleUrl)
print(poller)

result = poller.result()

print(result.documents)

for idx, document in enumerate(result.documents):
    print(f"--------Analyzing document #{idx + 1}--------")
    print(f"Document has type {document.doc_type}")
    print(f"Document has document type confidence {document.confidence}")
    print(f"Document was analyzed with model with ID {result.model_id}")
    for name, field in document.fields.items():
        field_value = field.value if field.value else field.content
        print(
            f"......found field of type '{field.value_type}' with value '{field_value}' and with confidence {field.confidence}"
        )

# iterate over tables, lines, and selection marks on each page
for page in result.pages:
    print(f"\nLines found on page {page.page_number}")
    for line in page.lines:
        print(f"...Line '{line.content}'")
    for word in page.words:
        print(f"...Word '{word.content}' has a confidence of {word.confidence}")
    if page.selection_marks:
        print(f"\nSelection marks found on page {page.page_number}")
        for selection_mark in page.selection_marks:
            print(
                f"...Selection mark is '{selection_mark.state}' and has a confidence of {selection_mark.confidence}"
            )

for i, table in enumerate(result.tables):
    print(f"\nTable {i + 1} can be found on page:")
    for region in table.bounding_regions:
        print(f"...{region.page_number}")
    for cell in table.cells:
        print(
            f"...Cell[{cell.row_index}][{cell.column_index}] has text '{cell.content}'"
        )
# Out:
# <azure.core.polling._poller.LROPoller object at 0x7f6e3726cca0>
# [AnalyzedDocument(doc_type=ELMModel:ELMModel, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=0.0, y=0.0), Point(x=8.2639, y=0.0), Point(x=8.2639, y=11.6806), Point(x=0.0, y=11.6806)]), BoundingRegion(page_number=2, polygon=[Point(x=0.0, y=0.0), Point(x=8.2639, y=0.0), Point(x=8.2639, y=11.6806), Point(x=0.0, y=11.6806)])], spans=[DocumentSpan(offset=0, length=2956)], fields={'Notification': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.995), 'DOB': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.987), 'DateOfOrder': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.605), 'DefendantName': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.749), 'DefendantAddress': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.995), 'PNCID': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.468), 'DestinationID': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.937), 'Court': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.919), 'EMHeading': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.544), 'Gender': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.995), 'CaseNumber': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.954), 'MobileNumber': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.671), 'CourtContact': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.974), 'URN': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.961)}, confidence=0.004)]
# --------Analyzing document #1--------
# Document has type ELMModel:ELMModel
# Document has document type confidence 0.004
# Document was analyzed with model with ID ELMModel
# ......found field of type 'string' with value 'None' and with confidence 0.995
# ......found field of type 'string' with value 'None' and with confidence 0.987
# ......found field of type 'string' with value 'None' and with confidence 0.605
# ......found field of type 'string' with value 'None' and with confidence 0.749
# ......found field of type 'string' with value 'None' and with confidence 0.995
# ......found field of type 'string' with value 'None' and with confidence 0.468
# ......found field of type 'string' with value 'None' and with confidence 0.937
# ......found field of type 'string' with value 'None' and with confidence 0.919
# ......found field of type 'string' with value 'None' and with confidence 0.544
# ......found field of type 'string' with value 'None' and with confidence 0.995
# ......found field of type 'string' with value 'None' and with confidence 0.954
# ......found field of type 'string' with value 'None' and with confidence 0.671
# ......found field of type 'string' with value 'None' and with confidence 0.974
# ......found field of type 'string' with value 'None' and with confidence 0.961
#
# Lines found on page 1
# ...Line 'Home Office'
# ...Line 'NOTIFICATION TO THE CONTRACTOR OF NEW, OR VARIATION,'
# ...Line 'TERMINATION OR WITHDRAWALTO AN EXISTING ELECTRONIC'
# ...Line 'MONITORING CONDITION'
# ...Line 'SECTION 1: PERSON DETAILS'
# ...Line 'New Monitoring Order'
# ...Line 'Tick box if this is a new Monitoring Order'
# ...Line 'Existing Monitoring Order'
# ...Line 'If applicable'
# ...Line 'EMOTesting'
# ...Line 'Amend Monitoring Order'
# ...Line 'Conditions (Curfew)'
# ...Line 'Terminate Monitoring Order'
# ...Line 'Tick box if monitoring is to cease'
# ...Line 'Withdraw Monitoring Order'
# ...Line 'Tick box if Monitoring Order to be withdrawn'
# ...Line '*= Mandatory Field'
# ...Line ''HO Reference Number'*'
# ...Line '11111111'
# ...Line 'Compliance and Enforcement Person'
# ...Line '22222222'
# ...Line 'Reference Number* (CEPR)'
# ...Line 'PERSON DETAILS'
# ...Line 'Family name*'
# ...Line 'Tom Test'
# ...Line 'Given name*'
# ...Line 'Tome'
# ...Line 'Date of birth*'
# ...Line '15/01/1989'
# ...Line 'Gender*'
# ...Line 'Male'
# ...Line 'Person photo identification*'
# ...Line 'Nationality*'
# ...Line 'British'
# ...Line 'Registered address*'
# ...Line 'Postcode*'
# ...Line 'Lord's Cricket Ground'
# ...Line 'St John's Wood Rd,'
# ...Line 'London NW8 8QN'
# ...Line 'Mobile phone number'
# ...Line '07111 223111'
# ...Line 'Email address'
# ...Line 'tome@example.com'
# ...Line 'Select primary language spoken'
# ...Line 'English'
# ...Line 'Enter primary language spoken if 'other''
# ...Line 'Enter language here'
# ...Line 'Distinguishing marks'
# ...Line 'Yes'
# ...Line 'No'
# ...Line 'Record any distinguishing marks here'
# ...Line 'Are there any known vulnerabilities'
# ...Line 'which would impact on the individual's'
# ...Line 'device induction? Note any adjustments'
# ...Line 'required.'
# ...Line 'X'
# ...Line 'Yes'
# ...Line 'No'
# ...Line 'If 'Yes' enter details here.'
# ...Line 'Specimen signature (if available)'
# ...Word 'Home' has a confidence of 0.989
# ...Word 'Office' has a confidence of 0.995
# ...Word 'NOTIFICATION' has a confidence of 0.993
# ...Word 'TO' has a confidence of 0.997
# ...Word 'THE' has a confidence of 0.996
# ...Word 'CONTRACTOR' has a confidence of 0.993
# ...Word 'OF' has a confidence of 0.997
# ...Word 'NEW,' has a confidence of 0.992
# ...Word 'OR' has a confidence of 0.995
# ...Word 'VARIATION,' has a confidence of 0.989
# ...Word 'TERMINATION' has a confidence of 0.994
# ...Word 'OR' has a confidence of 0.997
# ...Word 'WITHDRAWALTO' has a confidence of 0.993
# ...Word 'AN' has a confidence of 0.997
# ...Word 'EXISTING' has a confidence of 0.995
# ...Word 'ELECTRONIC' has a confidence of 0.994
# ...Word 'MONITORING' has a confidence of 0.993
# ...Word 'CONDITION' has a confidence of 0.993
# ...Word 'SECTION' has a confidence of 0.994
# ...Word '1:' has a confidence of 0.993
# ...Word 'PERSON' has a confidence of 0.994
# ...Word 'DETAILS' has a confidence of 0.993
# ...Word 'New' has a confidence of 0.997
# ...Word 'Monitoring' has a confidence of 0.994
# ...Word 'Order' has a confidence of 0.995
# ...Word 'Tick' has a confidence of 0.975
# ...Word 'box' has a confidence of 0.995
# ...Word 'if' has a confidence of 0.995
# ...Word 'this' has a confidence of 0.993
# ...Word 'is' has a confidence of 0.996
# ...Word 'a' has a confidence of 0.995
# ...Word 'new' has a confidence of 0.997
# ...Word 'Monitoring' has a confidence of 0.991
# ...Word 'Order' has a confidence of 0.995
# ...Word 'Existing' has a confidence of 0.984
# ...Word 'Monitoring' has a confidence of 0.98
# ...Word 'Order' has a confidence of 0.995
# ...Word 'If' has a confidence of 0.844
# ...Word 'applicable' has a confidence of 0.993
# ...Word 'EMOTesting' has a confidence of 0.993
# ...Word 'Amend' has a confidence of 0.995
# ...Word 'Monitoring' has a confidence of 0.989
# ...Word 'Order' has a confidence of 0.995
# ...Word 'Conditions' has a confidence of 0.993
# ...Word '(Curfew)' has a confidence of 0.992
# ...Word 'Terminate' has a confidence of 0.995
# ...Word 'Monitoring' has a confidence of 0.99
# ...Word 'Order' has a confidence of 0.995
# ...Word 'Tick' has a confidence of 0.993
# ...Word 'box' has a confidence of 0.995
# ...Word 'if' has a confidence of 0.995
# ...Word 'monitoring' has a confidence of 0.993
# ...Word 'is' has a confidence of 0.963
# ...Word 'to' has a confidence of 0.996
# ...Word 'cease' has a confidence of 0.995
# ...Word 'Withdraw' has a confidence of 0.995
# ...Word 'Monitoring' has a confidence of 0.994
# ...Word 'Order' has a confidence of 0.993
# ...Word 'Tick' has a confidence of 0.993
# ...Word 'box' has a confidence of 0.995
# ...Word 'if' has a confidence of 0.995
# ...Word 'Monitoring' has a confidence of 0.993
# ...Word 'Order' has a confidence of 0.995
# ...Word 'to' has a confidence of 0.997
# ...Word 'be' has a confidence of 0.979
# ...Word 'withdrawn' has a confidence of 0.992
# ...Word '*=' has a confidence of 0.98
# ...Word 'Mandatory' has a confidence of 0.994
# ...Word 'Field' has a confidence of 0.995
# ...Word ''HO' has a confidence of 0.86
# ...Word 'Reference' has a confidence of 0.993
# ...Word 'Number'*' has a confidence of 0.948
# ...Word '11111111' has a confidence of 0.995
# ...Word 'Compliance' has a confidence of 0.993
# ...Word 'and' has a confidence of 0.996
# ...Word 'Enforcement' has a confidence of 0.992
# ...Word 'Person' has a confidence of 0.995
# ...Word '22222222' has a confidence of 0.993
# ...Word 'Reference' has a confidence of 0.991
# ...Word 'Number*' has a confidence of 0.951
# ...Word '(CEPR)' has a confidence of 0.917
# ...Word 'PERSON' has a confidence of 0.995
# ...Word 'DETAILS' has a confidence of 0.993
# ...Word 'Family' has a confidence of 0.995
# ...Word 'name*' has a confidence of 0.992
# ...Word 'Tom' has a confidence of 0.997
# ...Word 'Test' has a confidence of 0.983
# ...Word 'Given' has a confidence of 0.995
# ...Word 'name*' has a confidence of 0.994
# ...Word 'Tome' has a confidence of 0.991
# ...Word 'Date' has a confidence of 0.992
# ...Word 'of' has a confidence of 0.945
# ...Word 'birth*' has a confidence of 0.994
# ...Word '15/01/1989' has a confidence of 0.993
# ...Word 'Gender*' has a confidence of 0.994
# ...Word 'Male' has a confidence of 0.993
# ...Word 'Person' has a confidence of 0.995
# ...Word 'photo' has a confidence of 0.995
# ...Word 'identification*' has a confidence of 0.975
# ...Word 'Nationality*' has a confidence of 0.993
# ...Word 'British' has a confidence of 0.995
# ...Word 'Registered' has a confidence of 0.994
# ...Word 'address*' has a confidence of 0.984
# ...Word 'Postcode*' has a confidence of 0.993
# ...Word 'Lord's' has a confidence of 0.994
# ...Word 'Cricket' has a confidence of 0.995
# ...Word 'Ground' has a confidence of 0.995
# ...Word 'St' has a confidence of 0.997
# ...Word 'John's' has a confidence of 0.994
# ...Word 'Wood' has a confidence of 0.993
# ...Word 'Rd,' has a confidence of 0.984
# ...Word 'London' has a confidence of 0.993
# ...Word 'NW8' has a confidence of 0.995
# ...Word '8QN' has a confidence of 0.929
# ...Word 'Mobile' has a confidence of 0.995
# ...Word 'phone' has a confidence of 0.995
# ...Word 'number' has a confidence of 0.995
# ...Word '07111' has a confidence of 0.993
# ...Word '223111' has a confidence of 0.995
# ...Word 'Email' has a confidence of 0.993
# ...Word 'address' has a confidence of 0.99
# ...Word 'tome@example.com' has a confidence of 0.951
# ...Word 'Select' has a confidence of 0.995
# ...Word 'primary' has a confidence of 0.994
# ...Word 'language' has a confidence of 0.993
# ...Word 'spoken' has a confidence of 0.994
# ...Word 'English' has a confidence of 0.995
# ...Word 'Enter' has a confidence of 0.995
# ...Word 'primary' has a confidence of 0.995
# ...Word 'language' has a confidence of 0.994
# ...Word 'spoken' has a confidence of 0.995
# ...Word 'if' has a confidence of 0.995
# ...Word ''other'' has a confidence of 0.961
# ...Word 'Enter' has a confidence of 0.995
# ...Word 'language' has a confidence of 0.994
# ...Word 'here' has a confidence of 0.993
# ...Word 'Distinguishing' has a confidence of 0.991
# ...Word 'marks' has a confidence of 0.995
# ...Word 'Yes' has a confidence of 0.983
# ...Word 'No' has a confidence of 0.995
# ...Word 'Record' has a confidence of 0.995
# ...Word 'any' has a confidence of 0.996
# ...Word 'distinguishing' has a confidence of 0.989
# ...Word 'marks' has a confidence of 0.995
# ...Word 'here' has a confidence of 0.993
# ...Word 'Are' has a confidence of 0.996
# ...Word 'there' has a confidence of 0.979
# ...Word 'any' has a confidence of 0.997
# ...Word 'known' has a confidence of 0.995
# ...Word 'vulnerabilities' has a confidence of 0.965
# ...Word 'which' has a confidence of 0.995
# ...Word 'would' has a confidence of 0.995
# ...Word 'impact' has a confidence of 0.979
# ...Word 'on' has a confidence of 0.997
# ...Word 'the' has a confidence of 0.995
# ...Word 'individual's' has a confidence of 0.961
# ...Word 'device' has a confidence of 0.989
# ...Word 'induction?' has a confidence of 0.993
# ...Word 'Note' has a confidence of 0.992
# ...Word 'any' has a confidence of 0.995
# ...Word 'adjustments' has a confidence of 0.984
# ...Word 'required.' has a confidence of 0.986
# ...Word 'X' has a confidence of 0.763
# ...Word 'Yes' has a confidence of 0.995
# ...Word 'No' has a confidence of 0.995
# ...Word 'If' has a confidence of 0.74
# ...Word ''Yes'' has a confidence of 0.909
# ...Word 'enter' has a confidence of 0.993
# ...Word 'details' has a confidence of 0.993
# ...Word 'here.' has a confidence of 0.993
# ...Word 'Specimen' has a confidence of 0.994
# ...Word 'signature' has a confidence of 0.993
# ...Word '(if' has a confidence of 0.983
# ...Word 'available)' has a confidence of 0.97
#
# Selection marks found on page 1
# ...Selection mark is 'selected' and has a confidence of 0.983
# ...Selection mark is 'unselected' and has a confidence of 0.971
# ...Selection mark is 'unselected' and has a confidence of 0.992
# ...Selection mark is 'unselected' and has a confidence of 0.997
# ...Selection mark is 'selected' and has a confidence of 0.995
# ...Selection mark is 'selected' and has a confidence of 0.996
# ...Selection mark is 'unselected' and has a confidence of 0.996
#
# Lines found on page 2
# ...Line 'Home Office'
# ...Line 'SECTION 2: RISK MANAGEMENT AND DEVICE DETAILS'
# ...Line 'RISK MANAGEMENT'
# ...Line 'MAPPA Level*'
# ...Line 'Level 1'
# ...Line 'Category 1'
# ...Line 'Level 2'
# ...Line 'Category 2'
# ...Line 'Level 3'
# ...Line 'Category 3'
# ...Line 'No MAPPA'
# ...Line 'Tick all boxes which apply*'
# ...Line 'a.'
# ...Line 'Violent offender'
# ...Line 'b.'
# ...Line 'Sexual offender'
# ...Line 'C.'
# ...Line 'Suicide/self-harm risk'
# ...Line 'd.'
# ...Line 'Disability'
# ...Line 'e.'
# ...Line 'Disruptive behaviour'
# ...Line 'f.'
# ...Line 'Medical concerns'
# ...Line 'g. x'
# ...Line 'Other'
# ...Line 'h.'
# ...Line 'No known risk factors'
# ...Line 'Enter details here if 'yes' to any of a'
# ...Line '- g'
# ...Line 'If this Monitoring Order involves a GPS Device type, complete the section below.'
# ...Line 'If it relates to a change of electronic monitoring bail conditions only, go to Section 3'
# ...Line 'GPS DEVICE ACTION REQUIRED'
# ...Line 'Details of GPS Device type to be issued'
# ...Line 'or changed.'
# ...Line 'C'
# ...Line 'New Device'
# ...Line 'New GPS with trail monitoring device'
# ...Line 'Includes an option to terminate'
# ...Line 'monitoring'
# ...Line 'Select one option from the list opposite'
# ...Line 'Location of visit if appropriate:'
# ...Line 'Date Device to be'
# ...Line 'issued/changed/removed*dd/mm/yyyy'
# ...Line 'Select date from calendar.'
# ...Line 'Time of appointment* (24 hr clock)'
# ...Line 'Click here to enter time (hh:mm)'
# ...Line 'Has Device already been removed?'
# ...Line 'X Yes'
# ...Line 'No'
# ...Line 'If 'yes', state location where Device is'
# ...Line 'held (if known)'
# ...Line 'Click here to enter full address and'
# ...Line 'postcode'
# ...Line 'Device Serial Number:'
# ...Line 'Home Monitoring Unit (HMU) required?'
# ...Line 'Yes'
# ...Line 'No'
# ...Line 'If 'yes', enter address where HMU is to'
# ...Line 'be installed'
# ...Line 'Click here to enter full address and'
# ...Line 'postcode'
# ...Line 'Date HMU to be installed dd/mm/yyyy'
# ...Line 'Select date from calendar.'
# ...Line 'Time HMU to be installed (24 hr clock)'
# ...Line 'Click here to enter time (hh:mm)'
# ...Word 'Home' has a confidence of 0.987
# ...Word 'Office' has a confidence of 0.995
# ...Word 'SECTION' has a confidence of 0.995
# ...Word '2:' has a confidence of 0.994
# ...Word 'RISK' has a confidence of 0.992
# ...Word 'MANAGEMENT' has a confidence of 0.992
# ...Word 'AND' has a confidence of 0.997
# ...Word 'DEVICE' has a confidence of 0.993
# ...Word 'DETAILS' has a confidence of 0.993
# ...Word 'RISK' has a confidence of 0.99
# ...Word 'MANAGEMENT' has a confidence of 0.993
# ...Word 'MAPPA' has a confidence of 0.991
# ...Word 'Level*' has a confidence of 0.932
# ...Word 'Level' has a confidence of 0.995
# ...Word '1' has a confidence of 0.995
# ...Word 'Category' has a confidence of 0.994
# ...Word '1' has a confidence of 0.931
# ...Word 'Level' has a confidence of 0.995
# ...Word '2' has a confidence of 0.997
# ...Word 'Category' has a confidence of 0.994
# ...Word '2' has a confidence of 0.997
# ...Word 'Level' has a confidence of 0.993
# ...Word '3' has a confidence of 0.996
# ...Word 'Category' has a confidence of 0.994
# ...Word '3' has a confidence of 0.996
# ...Word 'No' has a confidence of 0.995
# ...Word 'MAPPA' has a confidence of 0.995
# ...Word 'Tick' has a confidence of 0.992
# ...Word 'all' has a confidence of 0.996
# ...Word 'boxes' has a confidence of 0.995
# ...Word 'which' has a confidence of 0.995
# ...Word 'apply*' has a confidence of 0.974
# ...Word 'a.' has a confidence of 0.995
# ...Word 'Violent' has a confidence of 0.995
# ...Word 'offender' has a confidence of 0.995
# ...Word 'b.' has a confidence of 0.995
# ...Word 'Sexual' has a confidence of 0.995
# ...Word 'offender' has a confidence of 0.994
# ...Word 'C.' has a confidence of 0.914
# ...Word 'Suicide/self-harm' has a confidence of 0.989
# ...Word 'risk' has a confidence of 0.992
# ...Word 'd.' has a confidence of 0.995
# ...Word 'Disability' has a confidence of 0.993
# ...Word 'e.' has a confidence of 0.993
# ...Word 'Disruptive' has a confidence of 0.993
# ...Word 'behaviour' has a confidence of 0.993
# ...Word 'f.' has a confidence of 0.994
# ...Word 'Medical' has a confidence of 0.994
# ...Word 'concerns' has a confidence of 0.991
# ...Word 'g.' has a confidence of 0.975
# ...Word 'x' has a confidence of 0.838
# ...Word 'Other' has a confidence of 0.995
# ...Word 'h.' has a confidence of 0.995
# ...Word 'No' has a confidence of 0.996
# ...Word 'known' has a confidence of 0.993
# ...Word 'risk' has a confidence of 0.989
# ...Word 'factors' has a confidence of 0.995
# ...Word 'Enter' has a confidence of 0.995
# ...Word 'details' has a confidence of 0.993
# ...Word 'here' has a confidence of 0.993
# ...Word 'if' has a confidence of 0.925
# ...Word ''yes'' has a confidence of 0.983
# ...Word 'to' has a confidence of 0.995
# ...Word 'any' has a confidence of 0.995
# ...Word 'of' has a confidence of 0.995
# ...Word 'a' has a confidence of 0.995
# ...Word '-' has a confidence of 0.994
# ...Word 'g' has a confidence of 0.992
# ...Word 'If' has a confidence of 0.991
# ...Word 'this' has a confidence of 0.993
# ...Word 'Monitoring' has a confidence of 0.993
# ...Word 'Order' has a confidence of 0.989
# ...Word 'involves' has a confidence of 0.993
# ...Word 'a' has a confidence of 0.978
# ...Word 'GPS' has a confidence of 0.993
# ...Word 'Device' has a confidence of 0.995
# ...Word 'type,' has a confidence of 0.992
# ...Word 'complete' has a confidence of 0.993
# ...Word 'the' has a confidence of 0.996
# ...Word 'section' has a confidence of 0.994
# ...Word 'below.' has a confidence of 0.993
# ...Word 'If' has a confidence of 0.993
# ...Word 'it' has a confidence of 0.995
# ...Word 'relates' has a confidence of 0.994
# ...Word 'to' has a confidence of 0.996
# ...Word 'a' has a confidence of 0.995
# ...Word 'change' has a confidence of 0.995
# ...Word 'of' has a confidence of 0.995
# ...Word 'electronic' has a confidence of 0.993
# ...Word 'monitoring' has a confidence of 0.99
# ...Word 'bail' has a confidence of 0.993
# ...Word 'conditions' has a confidence of 0.993
# ...Word 'only,' has a confidence of 0.993
# ...Word 'go' has a confidence of 0.995
# ...Word 'to' has a confidence of 0.995
# ...Word 'Section' has a confidence of 0.994
# ...Word '3' has a confidence of 0.995
# ...Word 'GPS' has a confidence of 0.995
# ...Word 'DEVICE' has a confidence of 0.99
# ...Word 'ACTION' has a confidence of 0.993
# ...Word 'REQUIRED' has a confidence of 0.973
# ...Word 'Details' has a confidence of 0.994
# ...Word 'of' has a confidence of 0.948
# ...Word 'GPS' has a confidence of 0.995
# ...Word 'Device' has a confidence of 0.993
# ...Word 'type' has a confidence of 0.985
# ...Word 'to' has a confidence of 0.995
# ...Word 'be' has a confidence of 0.995
# ...Word 'issued' has a confidence of 0.994
# ...Word 'or' has a confidence of 0.995
# ...Word 'changed.' has a confidence of 0.994
# ...Word 'C' has a confidence of 0.879
# ...Word 'New' has a confidence of 0.994
# ...Word 'Device' has a confidence of 0.991
# ...Word 'New' has a confidence of 0.996
# ...Word 'GPS' has a confidence of 0.994
# ...Word 'with' has a confidence of 0.982
# ...Word 'trail' has a confidence of 0.995
# ...Word 'monitoring' has a confidence of 0.993
# ...Word 'device' has a confidence of 0.987
# ...Word 'Includes' has a confidence of 0.948
# ...Word 'an' has a confidence of 0.996
# ...Word 'option' has a confidence of 0.993
# ...Word 'to' has a confidence of 0.996
# ...Word 'terminate' has a confidence of 0.983
# ...Word 'monitoring' has a confidence of 0.993
# ...Word 'Select' has a confidence of 0.994
# ...Word 'one' has a confidence of 0.995
# ...Word 'option' has a confidence of 0.994
# ...Word 'from' has a confidence of 0.993
# ...Word 'the' has a confidence of 0.997
# ...Word 'list' has a confidence of 0.993
# ...Word 'opposite' has a confidence of 0.993
# ...Word 'Location' has a confidence of 0.993
# ...Word 'of' has a confidence of 0.995
# ...Word 'visit' has a confidence of 0.995
# ...Word 'if' has a confidence of 0.995
# ...Word 'appropriate:' has a confidence of 0.971
# ...Word 'Date' has a confidence of 0.993
# ...Word 'Device' has a confidence of 0.995
# ...Word 'to' has a confidence of 0.996
# ...Word 'be' has a confidence of 0.995
# ...Word 'issued/changed/removed*dd/mm/yyyy' has a confidence of 0.938
# ...Word 'Select' has a confidence of 0.995
# ...Word 'date' has a confidence of 0.984
# ...Word 'from' has a confidence of 0.993
# ...Word 'calendar.' has a confidence of 0.993
# ...Word 'Time' has a confidence of 0.985
# ...Word 'of' has a confidence of 0.996
# ...Word 'appointment*' has a confidence of 0.972
# ...Word '(24' has a confidence of 0.983
# ...Word 'hr' has a confidence of 0.995
# ...Word 'clock)' has a confidence of 0.993
# ...Word 'Click' has a confidence of 0.995
# ...Word 'here' has a confidence of 0.993
# ...Word 'to' has a confidence of 0.984
# ...Word 'enter' has a confidence of 0.967
# ...Word 'time' has a confidence of 0.992
# ...Word '(hh:mm)' has a confidence of 0.961
# ...Word 'Has' has a confidence of 0.996
# ...Word 'Device' has a confidence of 0.994
# ...Word 'already' has a confidence of 0.994
# ...Word 'been' has a confidence of 0.99
# ...Word 'removed?' has a confidence of 0.995
# ...Word 'X' has a confidence of 0.746
# ...Word 'Yes' has a confidence of 0.995
# ...Word 'No' has a confidence of 0.993
# ...Word 'If' has a confidence of 0.907
# ...Word ''yes',' has a confidence of 0.927
# ...Word 'state' has a confidence of 0.995
# ...Word 'location' has a confidence of 0.987
# ...Word 'where' has a confidence of 0.993
# ...Word 'Device' has a confidence of 0.994
# ...Word 'is' has a confidence of 0.995
# ...Word 'held' has a confidence of 0.993
# ...Word '(if' has a confidence of 0.995
# ...Word 'known)' has a confidence of 0.995
# ...Word 'Click' has a confidence of 0.994
# ...Word 'here' has a confidence of 0.993
# ...Word 'to' has a confidence of 0.997
# ...Word 'enter' has a confidence of 0.995
# ...Word 'full' has a confidence of 0.993
# ...Word 'address' has a confidence of 0.995
# ...Word 'and' has a confidence of 0.996
# ...Word 'postcode' has a confidence of 0.983
# ...Word 'Device' has a confidence of 0.995
# ...Word 'Serial' has a confidence of 0.995
# ...Word 'Number:' has a confidence of 0.99
# ...Word 'Home' has a confidence of 0.993
# ...Word 'Monitoring' has a confidence of 0.993
# ...Word 'Unit' has a confidence of 0.992
# ...Word '(HMU)' has a confidence of 0.994
# ...Word 'required?' has a confidence of 0.991
# ...Word 'Yes' has a confidence of 0.995
# ...Word 'No' has a confidence of 0.995
# ...Word 'If' has a confidence of 0.789
# ...Word ''yes',' has a confidence of 0.978
# ...Word 'enter' has a confidence of 0.995
# ...Word 'address' has a confidence of 0.994
# ...Word 'where' has a confidence of 0.995
# ...Word 'HMU' has a confidence of 0.995
# ...Word 'is' has a confidence of 0.995
# ...Word 'to' has a confidence of 0.995
# ...Word 'be' has a confidence of 0.996
# ...Word 'installed' has a confidence of 0.994
# ...Word 'Click' has a confidence of 0.995
# ...Word 'here' has a confidence of 0.993
# ...Word 'to' has a confidence of 0.996
# ...Word 'enter' has a confidence of 0.995
# ...Word 'full' has a confidence of 0.993
# ...Word 'address' has a confidence of 0.994
# ...Word 'and' has a confidence of 0.997
# ...Word 'postcode' has a confidence of 0.994
# ...Word 'Date' has a confidence of 0.987
# ...Word 'HMU' has a confidence of 0.992
# ...Word 'to' has a confidence of 0.996
# ...Word 'be' has a confidence of 0.995
# ...Word 'installed' has a confidence of 0.993
# ...Word 'dd/mm/yyyy' has a confidence of 0.99
# ...Word 'Select' has a confidence of 0.995
# ...Word 'date' has a confidence of 0.993
# ...Word 'from' has a confidence of 0.983
# ...Word 'calendar.' has a confidence of 0.993
# ...Word 'Time' has a confidence of 0.993
# ...Word 'HMU' has a confidence of 0.995
# ...Word 'to' has a confidence of 0.996
# ...Word 'be' has a confidence of 0.996
# ...Word 'installed' has a confidence of 0.993
# ...Word '(24' has a confidence of 0.995
# ...Word 'hr' has a confidence of 0.995
# ...Word 'clock)' has a confidence of 0.994
# ...Word 'Click' has a confidence of 0.995
# ...Word 'here' has a confidence of 0.992
# ...Word 'to' has a confidence of 0.996
# ...Word 'enter' has a confidence of 0.995
# ...Word 'time' has a confidence of 0.992
# ...Word '(hh:mm)' has a confidence of 0.962
#
# Selection marks found on page 2
# ...Selection mark is 'unselected' and has a confidence of 0.995
# ...Selection mark is 'unselected' and has a confidence of 1.0
# ...Selection mark is 'unselected' and has a confidence of 0.992
# ...Selection mark is 'unselected' and has a confidence of 0.997
# ...Selection mark is 'selected' and has a confidence of 0.987
# ...Selection mark is 'unselected' and has a confidence of 0.995
# ...Selection mark is 'unselected' and has a confidence of 0.992
# ...Selection mark is 'unselected' and has a confidence of 0.997
# ...Selection mark is 'unselected' and has a confidence of 1.0
# ...Selection mark is 'unselected' and has a confidence of 0.995
# ...Selection mark is 'unselected' and has a confidence of 0.995
# ...Selection mark is 'unselected' and has a confidence of 0.995
# ...Selection mark is 'unselected' and has a confidence of 0.997
# ...Selection mark is 'selected' and has a confidence of 0.995
# ...Selection mark is 'unselected' and has a confidence of 0.995
# ...Selection mark is 'unselected' and has a confidence of 0.98
# ...Selection mark is 'selected' and has a confidence of 0.996
# ...Selection mark is 'unselected' and has a confidence of 0.996
# ...Selection mark is 'selected' and has a confidence of 0.993
# ...Selection mark is 'unselected' and has a confidence of 0.997
#
# Table 1 can be found on page:
# ...1
# ...Cell[0][0] has text 'SECTION 1: PERSON DETAILS'
# ...Cell[1][0] has text 'New Monitoring Order'
# ...Cell[1][1] has text ':selected: Tick box if this is a new Monitoring Order'
# ...Cell[2][0] has text 'Existing Monitoring Order If applicable'
# ...Cell[2][1] has text 'EMOTesting'
# ...Cell[3][0] has text 'Amend Monitoring Order'
# ...Cell[3][1] has text 'Conditions (Curfew)'
# ...Cell[4][0] has text 'Terminate Monitoring Order'
# ...Cell[4][1] has text ':unselected: Tick box if monitoring is to cease'
# ...Cell[5][0] has text 'Withdraw Monitoring Order'
# ...Cell[5][1] has text ':unselected: Tick box if Monitoring Order to be withdrawn'
#
# Table 2 can be found on page:
# ...1
# ...Cell[0][0] has text ''HO Reference Number'*'
# ...Cell[0][1] has text '11111111'
# ...Cell[1][0] has text 'Compliance and Enforcement Person'
# ...Cell[1][1] has text '22222222'
# ...Cell[2][0] has text 'Reference Number* (CEPR)'
# ...Cell[2][1] has text ''
#
# Table 3 can be found on page:
# ...1
# ...Cell[0][0] has text 'Family name*'
# ...Cell[0][1] has text 'Tom Test'
# ...Cell[1][0] has text 'Given name*'
# ...Cell[1][1] has text 'Tome'
# ...Cell[2][0] has text 'Date of birth*'
# ...Cell[2][1] has text '15/01/1989'
# ...Cell[3][0] has text 'Gender*'
# ...Cell[3][1] has text 'Male'
# ...Cell[4][0] has text 'Person photo identification*'
# ...Cell[4][1] has text ''
# ...Cell[5][0] has text 'Nationality*'
# ...Cell[5][1] has text 'British'
# ...Cell[6][0] has text 'Registered address* Postcode*'
# ...Cell[6][1] has text 'Lord's Cricket Ground St John's Wood Rd, London NW8 8QN'
# ...Cell[7][0] has text 'Mobile phone number'
# ...Cell[7][1] has text '07111 223111'
# ...Cell[8][0] has text 'Email address'
# ...Cell[8][1] has text 'tome@example.com'
# ...Cell[9][0] has text 'Select primary language spoken'
# ...Cell[9][1] has text 'English'
# ...Cell[10][0] has text 'Enter primary language spoken if 'other''
# ...Cell[10][1] has text 'Enter language here'
# ...Cell[11][0] has text 'Distinguishing marks'
# ...Cell[11][1] has text ':unselected: Yes :selected: No Record any distinguishing marks here'
# ...Cell[12][0] has text 'Are there any known vulnerabilities which would impact on the individual's device induction? Note any adjustments required.'
# ...Cell[12][1] has text ':selected: X Yes :unselected: No If 'Yes' enter details here.'
# ...Cell[13][0] has text 'Specimen signature (if available)'
# ...Cell[13][1] has text ''
#
# Table 4 can be found on page:
# ...2
# ...Cell[0][0] has text 'MAPPA Level*'
# ...Cell[0][1] has text ':unselected: Level 1 :unselected: Category 1'
# ...Cell[1][1] has text ':unselected: Level 2 :unselected: Category 2'
# ...Cell[2][1] has text ':selected: Level 3 :unselected: Category 3'
# ...Cell[3][1] has text ':unselected: No MAPPA'
# ...Cell[4][0] has text 'Tick all boxes which apply*'
# ...Cell[4][1] has text 'a. :unselected: Violent offender'
# ...Cell[5][1] has text 'b. :unselected: Sexual offender C. :unselected: Suicide/self-harm risk d. :unselected: Disability'
# ...Cell[6][1] has text 'e. :unselected: Disruptive behaviour'
# ...Cell[7][1] has text 'f. :unselected: Medical concerns'
# ...Cell[8][1] has text 'g. x :selected: Other'
# ...Cell[9][1] has text 'h. :unselected: No known risk factors'
# ...Cell[10][1] has text 'Enter details here if 'yes' to any of a - g'
#
# Table 5 can be found on page:
# ...2
# ...Cell[0][0] has text 'If it relates to a change of electronic
# GPS DEVICE ACTION REQUIRED'
# ...Cell[0][1] has text 'bail conditions only, go to Section 3'
# ...Cell[1][0] has text 'Details of GPS Device type to be issued or changed.'
# ...Cell[1][1] has text ':unselected: C New Device New GPS with trail monitoring device'
# ...Cell[2][0] has text 'Includes an option to terminate monitoring'
# ...Cell[2][1] has text ''
# ...Cell[3][0] has text 'Select one option from the list opposite'
# ...Cell[3][1] has text ''
# ...Cell[4][0] has text 'Location of visit if appropriate:'
# ...Cell[4][1] has text ''
# ...Cell[5][0] has text 'Date Device to be issued/changed/removed*dd/mm/yyyy'
# ...Cell[5][1] has text 'Select date from calendar.'
# ...Cell[6][0] has text 'Time of appointment* (24 hr clock)'
# ...Cell[6][1] has text 'Click here to enter time (hh:mm)'
# ...Cell[7][0] has text 'Has Device already been removed?'
# ...Cell[7][1] has text ':selected: X Yes :unselected: No'
# ...Cell[8][0] has text 'If 'yes', state location where Device is held (if known)'
# ...Cell[8][1] has text 'Click here to enter full address and postcode'
# ...Cell[9][0] has text 'Device Serial Number:'
# ...Cell[9][1] has text ''
# ...Cell[10][0] has text 'Home Monitoring Unit (HMU) required?'
# ...Cell[10][1] has text ':selected: Yes :unselected: No'
# ...Cell[11][0] has text 'If 'yes', enter address where HMU is to be installed'
# ...Cell[11][1] has text 'Click here to enter full address and postcode'
# ...Cell[12][0] has text 'Date HMU to be installed dd/mm/yyyy'
# ...Cell[12][1] has text 'Select date from calendar.'
# ...Cell[13][0] has text 'Time HMU to be installed (24 hr clock)'
# ...Cell[13][1] has text 'Click here to enter time (hh:mm)'

# %% [markdown]
# ## F. Extracted document insights/ response as table of Key Value Pair using custom model

# %%
# Get the document insights as key / value table
from tabulate import tabulate

data = []

# Display key value pairs
for idx, document in enumerate(result.documents):
    print()
    print("--------Analyzing document #{}--------".format(idx + 1))
    print("Document has type {}".format(document.doc_type))
    print("Document has document type confidence {}".format(
        document.confidence))
    print("Document was analyzed with model with ID {}".format(
        result.model_id))
    print()
    for name, field in document.fields.items():
        field_value = field.value if field.value else field.content
        if field.value_type != 'list':
            data.append([name, field.value, field.confidence])

data.sort()
print(tabulate(data, headers=[
    'Label', 'Value', 'Confidence'], tablefmt='fancy_grid'))

# Display table data
for i, table in enumerate(result.tables):

    row_index = 1
    hdr = []
    rows = []
    row = []

    print("\nTable {} can be found on page:".format(i + 1))
    # for region in table.bounding_regions:
    #     print("...{}".format(i + 1, region.page_number))

    for cell in table.cells:
        if cell.row_index == 0:
            hdr.append(cell.content)
        else:
            if row_index != cell.row_index:
                rows.append(row)
                row_index = cell.row_index
                row = []

            row.append(cell.content)

    rows.append(row)
    print(tabulate(rows, headers=hdr, tablefmt='fancy_grid'))
# Out:
# --------Analyzing document #1--------
# Document has type ELMModel:ELMModel
# Document has document type confidence 0.004
# Document was analyzed with model with ID ELMModel
#
# ╒══════════════════╤═════════╤══════════════╕
# │ Label            │ Value   │   Confidence │
# ╞══════════════════╪═════════╪══════════════╡
# │ CaseNumber       │         │        0.954 │
# ├──────────────────┼─────────┼──────────────┤
# │ Court            │         │        0.919 │
# ├──────────────────┼─────────┼──────────────┤
# │ CourtContact     │         │        0.974 │
# ├──────────────────┼─────────┼──────────────┤
# │ DOB              │         │        0.987 │
# ├──────────────────┼─────────┼──────────────┤
# │ DateOfOrder      │         │        0.605 │
# ├──────────────────┼─────────┼──────────────┤
# │ DefendantAddress │         │        0.995 │
# ├──────────────────┼─────────┼──────────────┤
# │ DefendantName    │         │        0.749 │
# ├──────────────────┼─────────┼──────────────┤
# │ DestinationID    │         │        0.937 │
# ├──────────────────┼─────────┼──────────────┤
# │ EMHeading        │         │        0.544 │
# ├──────────────────┼─────────┼──────────────┤
# │ Gender           │         │        0.995 │
# ├──────────────────┼─────────┼──────────────┤
# │ MobileNumber     │         │        0.671 │
# ├──────────────────┼─────────┼──────────────┤
# │ Notification     │         │        0.995 │
# ├──────────────────┼─────────┼──────────────┤
# │ PNCID            │         │        0.468 │
# ├──────────────────┼─────────┼──────────────┤
# │ URN              │         │        0.961 │
# ╘══════════════════╧═════════╧══════════════╛
#
# Table 1 can be found on page:
# ╒═════════════════════════════════════════╤═══════════════════════════════════════════════════════════╕
# │                                         │ SECTION 1: PERSON DETAILS                                 │
# ╞═════════════════════════════════════════╪═══════════════════════════════════════════════════════════╡
# │ New Monitoring Order                    │ :selected: Tick box if this is a new Monitoring Order     │
# ├─────────────────────────────────────────┼───────────────────────────────────────────────────────────┤
# │ Existing Monitoring Order If applicable │ EMOTesting                                                │
# ├─────────────────────────────────────────┼───────────────────────────────────────────────────────────┤
# │ Amend Monitoring Order                  │ Conditions (Curfew)                                       │
# ├─────────────────────────────────────────┼───────────────────────────────────────────────────────────┤
# │ Terminate Monitoring Order              │ :unselected: Tick box if monitoring is to cease           │
# ├─────────────────────────────────────────┼───────────────────────────────────────────────────────────┤
# │ Withdraw Monitoring Order               │ :unselected: Tick box if Monitoring Order to be withdrawn │
# ╘═════════════════════════════════════════╧═══════════════════════════════════════════════════════════╛
#
# Table 2 can be found on page:
# ╒═══════════════════════════════════╤════════════╕
# │ 'HO Reference Number'*            │ 11111111   │
# ╞═══════════════════════════════════╪════════════╡
# │ Compliance and Enforcement Person │ 22222222   │
# ├───────────────────────────────────┼────────────┤
# │ Reference Number* (CEPR)          │            │
# ╘═══════════════════════════════════╧════════════╛
#
# Table 3 can be found on page:
# ╒═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╤═════════════════════════════════════════════════════════════════════╕
# │ Family name*                                                                                                                │ Tom Test                                                            │
# ╞═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╪═════════════════════════════════════════════════════════════════════╡
# │ Given name*                                                                                                                 │ Tome                                                                │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────┤
# │ Date of birth*                                                                                                              │ 15/01/1989                                                          │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────┤
# │ Gender*                                                                                                                     │ Male                                                                │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────┤
# │ Person photo identification*                                                                                                │                                                                     │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────┤
# │ Nationality*                                                                                                                │ British                                                             │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────┤
# │ Registered address* Postcode*                                                                                               │ Lord's Cricket Ground St John's Wood Rd, London NW8 8QN             │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────┤
# │ Mobile phone number                                                                                                         │ 07111 223111                                                        │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────┤
# │ Email address                                                                                                               │ tome@example.com                                                    │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────┤
# │ Select primary language spoken                                                                                              │ English                                                             │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────┤
# │ Enter primary language spoken if 'other'                                                                                    │ Enter language here                                                 │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────┤
# │ Distinguishing marks                                                                                                        │ :unselected: Yes :selected: No Record any distinguishing marks here │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────┤
# │ Are there any known vulnerabilities which would impact on the individual's device induction? Note any adjustments required. │ :selected: X Yes :unselected: No If 'Yes' enter details here.       │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────┤
# │ Specimen signature (if available)                                                                                           │                                                                     │
# ╘═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╧═════════════════════════════════════════════════════════════════════╛
#
# Table 4 can be found on page:
# ╒═══════════════════════════════════════════════════════════════════════════════════════════════════╤════════════════════════════════════════════════╕
# │ MAPPA Level*                                                                                      │ :unselected: Level 1 :unselected: Category 1   │
# ╞═══════════════════════════════════════════════════════════════════════════════════════════════════╪════════════════════════════════════════════════╡
# │ :unselected: Level 2 :unselected: Category 2                                                      │                                                │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ :selected: Level 3 :unselected: Category 3                                                        │                                                │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ :unselected: No MAPPA                                                                             │                                                │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ Tick all boxes which apply*                                                                       │ a. :unselected: Violent offender               │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ b. :unselected: Sexual offender C. :unselected: Suicide/self-harm risk d. :unselected: Disability │                                                │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ e. :unselected: Disruptive behaviour                                                              │                                                │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ f. :unselected: Medical concerns                                                                  │                                                │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ g. x :selected: Other                                                                             │                                                │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ h. :unselected: No known risk factors                                                             │                                                │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────┤
# │ Enter details here if 'yes' to any of a - g                                                       │                                                │
# ╘═══════════════════════════════════════════════════════════════════════════════════════════════════╧════════════════════════════════════════════════╛
#
# Table 5 can be found on page:
# ╒══════════════════════════════════════════════════════════╤════════════════════════════════════════════════════════════════╕
# │ If it relates to a change of electronic                  │ bail conditions only, go to Section 3                          │
# │ GPS DEVICE ACTION REQUIRED                               │                                                                │
# ╞══════════════════════════════════════════════════════════╪════════════════════════════════════════════════════════════════╡
# │ Details of GPS Device type to be issued or changed.      │ :unselected: C New Device New GPS with trail monitoring device │
# ├──────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────┤
# │ Includes an option to terminate monitoring               │                                                                │
# ├──────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────┤
# │ Select one option from the list opposite                 │                                                                │
# ├──────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────┤
# │ Location of visit if appropriate:                        │                                                                │
# ├──────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────┤
# │ Date Device to be issued/changed/removed*dd/mm/yyyy      │ Select date from calendar.                                     │
# ├──────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────┤
# │ Time of appointment* (24 hr clock)                       │ Click here to enter time (hh:mm)                               │
# ├──────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────┤
# │ Has Device already been removed?                         │ :selected: X Yes :unselected: No                               │
# ├──────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────┤
# │ If 'yes', state location where Device is held (if known) │ Click here to enter full address and postcode                  │
# ├──────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────┤
# │ Device Serial Number:                                    │                                                                │
# ├──────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────┤
# │ Home Monitoring Unit (HMU) required?                     │ :selected: Yes :unselected: No                                 │
# ├──────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────┤
# │ If 'yes', enter address where HMU is to be installed     │ Click here to enter full address and postcode                  │
# ├──────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────┤
# │ Date HMU to be installed dd/mm/yyyy                      │ Select date from calendar.                                     │
# ├──────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────┤
# │ Time HMU to be installed (24 hr clock)                   │ Click here to enter time (hh:mm)                               │
# ╘══════════════════════════════════════════════════════════╧════════════════════════════════════════════════════════════════╛

# %% [markdown]
# ## G. Extracted document insights/ response as a JSON format

# %%
# Import necessary libraries
# json for handling JSON data
# datetime and time for generating timestamps
# AzureJSONEncoder for serializing Python objects to JSON
# urlparse for parsing URLs
import json
import datetime
import time
from azure.core.serialization import AzureJSONEncoder
from urllib.parse import urlparse


# generate the unique file name
filename = datetime.datetime.fromtimestamp(time.time()).strftime('%Y%m%d%H%M%S')+"_"+os.path.splitext(os.path.basename(urlparse(sampleUrl).path))[0]

# parse and format the model response json 
# convert the received model to a dictionary
analyze_result_dict = result.to_dict()

# save the dictionary as JSON content in a JSON file, use the AzureJSONEncoder
# to help make types, such as dates, JSON serializable
with open(str(filename), 'w') as f:
        json.dump(analyze_result_dict, f, cls=AzureJSONEncoder,indent=4)

# convert the dictionary back to the original model
model = AnalyzeResult.from_dict(analyze_result_dict)
print("--------------JSON Response from Model Starts---------------------")
# use the model as normal
print("Model ID: '{}'".format(model.model_id))
print("Number of pages analyzed {}".format(len(model.pages)))
print("API version used: {}".format(model.api_version))
print(json.dumps(analyze_result_dict,cls=AzureJSONEncoder,indent=4))
print("--------------JSON Response from Model Ends---------------------")
# Out:
# --------------JSON Response from Model Starts---------------------
# Model ID: 'ELMModel'
# Number of pages analyzed 2
# API version used: 2023-07-31
# {
#     "api_version": "2023-07-31",
#     "model_id": "ELMModel",
#     "content": "Home Office\nNOTIFICATION TO THE CONTRACTOR OF NEW, OR VARIATION, TERMINATION OR WITHDRAWALTO AN EXISTING ELECTRONIC MONITORING CONDITION\nSECTION 1: PERSON DETAILS\nNew Monitoring Order :selected: Tick box if this is a new Monitoring Order\nExisting Monitoring Order If applicable\nEMOTesting\nAmend Monitoring Order\nConditions (Curfew)\nTerminate Monitoring Order :unselected: Tick box if monitoring is to cease\nWithdraw Monitoring Order :unselected: Tick box if Monitoring Order to be withdrawn\n*= Mandatory Field\n'HO Reference Number'*\n11111111\nCompliance and Enforcement Person\n22222222\nReference Number* (CEPR)\nPERSON DETAILS\nFamily name*\nTom Test\nGiven name*\nTome\nDate of birth*\n15/01/1989\nGender*\nMale\nPerson photo identification*\nNationality*\nBritish\nRegistered address* Postcode*\nLord's Cricket Ground St John's Wood Rd, London NW8 8QN\nMobile phone number\n07111 223111\nEmail address\ntome@example.com\nSelect primary language spoken\nEnglish\nEnter primary language spoken if 'other'\nEnter language here\nDistinguishing marks :unselected: Yes :selected: No Record any distinguishing marks here\nAre there any known vulnerabilities which would impact on the individual's device induction? Note any adjustments required. :selected: X Yes :unselected: No If 'Yes' enter details here.\nSpecimen signature (if available)\nHome Office\nSECTION 2: RISK MANAGEMENT AND DEVICE DETAILS\nRISK MANAGEMENT\nMAPPA Level* :unselected: Level 1 :unselected: Category 1 :unselected: Level 2 :unselected: Category 2 :selected: Level 3 :unselected: Category 3 :unselected: No MAPPA\nTick all boxes which apply*\na. :unselected: Violent offender\nb. :unselected: Sexual offender C. :unselected: Suicide/self-harm risk d. :unselected: Disability\ne. :unselected: Disruptive behaviour\nf. :unselected: Medical concerns\ng. x :selected: Other\nh. :unselected: No known risk factors\nEnter details here if 'yes' to any of a - g\nIf this Monitoring Order involves a GPS Device type, complete the section below. If it relates to a change of electronic monitoring bail conditions only, go to Section 3\nGPS DEVICE ACTION REQUIRED\nDetails of GPS Device type to be issued or changed. :unselected: C New Device New GPS with trail monitoring device\nIncludes an option to terminate monitoring\nSelect one option from the list opposite\nLocation of visit if appropriate:\nDate Device to be issued/changed/removed*dd/mm/yyyy\nSelect date from calendar.\nTime of appointment* (24 hr clock)\nClick here to enter time (hh:mm)\nHas Device already been removed? :selected: X Yes :unselected: No\nIf 'yes', state location where Device is held (if known)\nClick here to enter full address and postcode\nDevice Serial Number:\nHome Monitoring Unit (HMU) required? :selected: Yes :unselected: No\nIf 'yes', enter address where HMU is to be installed\nClick here to enter full address and postcode\nDate HMU to be installed dd/mm/yyyy\nSelect date from calendar.\nTime HMU to be installed (24 hr clock)\nClick here to enter time (hh:mm)",
#     "languages": [],
#     "pages": [
#         {
#             "page_number": 1,
#             "angle": null,
#             "width": 8.2639,
#             "height": 11.6806,
#             "unit": "inch",
#             "lines": [
#                 {
#                     "content": "Home Office",
#                     "polygon": [
#                         {
#                             "x": 0.6946,
#                             "y": 0.5222
#                         },
#                         {
#                             "x": 1.5412,
#                             "y": 0.5222
#                         },
#                         {
#                             "x": 1.5412,
#                             "y": 0.6793
#                         },
#                         {
#                             "x": 0.6946,
#                             "y": 0.6793
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 0,
#                             "length": 11
#                         }
#                     ]
#                 },
#                 {
#                     "content": "NOTIFICATION TO THE CONTRACTOR OF NEW, OR VARIATION,",
#                     "polygon": [
#                         {
#                             "x": 1.7542,
#                             "y": 0.9987
#                         },
#                         {
#                             "x": 6.9153,
#                             "y": 0.9987
#                         },
#                         {
#                             "x": 6.9153,
#                             "y": 1.1914
#                         },
#                         {
#                             "x": 1.7542,
#                             "y": 1.1863
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 12,
#                             "length": 52
#                         }
#                     ]
#                 },
#                 {
#                     "content": "TERMINATION OR WITHDRAWALTO AN EXISTING ELECTRONIC",
#                     "polygon": [
#                         {
#                             "x": 1.7592,
#                             "y": 1.1914
#                         },
#                         {
#                             "x": 6.9001,
#                             "y": 1.1914
#                         },
#                         {
#                             "x": 6.9001,
#                             "y": 1.3688
#                         },
#                         {
#                             "x": 1.7592,
#                             "y": 1.3688
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 65,
#                             "length": 50
#                         }
#                     ]
#                 },
#                 {
#                     "content": "MONITORING CONDITION",
#                     "polygon": [
#                         {
#                             "x": 3.2903,
#                             "y": 1.3891
#                         },
#                         {
#                             "x": 5.3741,
#                             "y": 1.384
#                         },
#                         {
#                             "x": 5.3741,
#                             "y": 1.5513
#                         },
#                         {
#                             "x": 3.2903,
#                             "y": 1.5564
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 116,
#                             "length": 20
#                         }
#                     ]
#                 },
#                 {
#                     "content": "SECTION 1: PERSON DETAILS",
#                     "polygon": [
#                         {
#                             "x": 1.3131,
#                             "y": 1.7643
#                         },
#                         {
#                             "x": 3.5692,
#                             "y": 1.7643
#                         },
#                         {
#                             "x": 3.5692,
#                             "y": 1.9214
#                         },
#                         {
#                             "x": 1.3131,
#                             "y": 1.9214
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 137,
#                             "length": 25
#                         }
#                     ]
#                 },
#                 {
#                     "content": "New Monitoring Order",
#                     "polygon": [
#                         {
#                             "x": 1.3232,
#                             "y": 2.0127
#                         },
#                         {
#                             "x": 2.9405,
#                             "y": 2.0177
#                         },
#                         {
#                             "x": 2.9405,
#                             "y": 2.1901
#                         },
#                         {
#                             "x": 1.3232,
#                             "y": 2.18
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 163,
#                             "length": 20
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Tick box if this is a new Monitoring Order",
#                     "polygon": [
#                         {
#                             "x": 3.8632,
#                             "y": 2.0127
#                         },
#                         {
#                             "x": 6.6669,
#                             "y": 2.0127
#                         },
#                         {
#                             "x": 6.6669,
#                             "y": 2.185
#                         },
#                         {
#                             "x": 3.8632,
#                             "y": 2.1749
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 195,
#                             "length": 42
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Existing Monitoring Order",
#                     "polygon": [
#                         {
#                             "x": 1.3283,
#                             "y": 2.2205
#                         },
#                         {
#                             "x": 3.2194,
#                             "y": 2.2205
#                         },
#                         {
#                             "x": 3.2194,
#                             "y": 2.3929
#                         },
#                         {
#                             "x": 1.3283,
#                             "y": 2.3929
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 238,
#                             "length": 25
#                         }
#                     ]
#                 },
#                 {
#                     "content": "If applicable",
#                     "polygon": [
#                         {
#                             "x": 1.3435,
#                             "y": 2.398
#                         },
#                         {
#                             "x": 2.1648,
#                             "y": 2.398
#                         },
#                         {
#                             "x": 2.1648,
#                             "y": 2.5551
#                         },
#                         {
#                             "x": 1.3435,
#                             "y": 2.5551
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 264,
#                             "length": 13
#                         }
#                     ]
#                 },
#                 {
#                     "content": "EMOTesting",
#                     "polygon": [
#                         {
#                             "x": 3.7111,
#                             "y": 2.3016
#                         },
#                         {
#                             "x": 4.5629,
#                             "y": 2.3016
#                         },
#                         {
#                             "x": 4.5629,
#                             "y": 2.4841
#                         },
#                         {
#                             "x": 3.7111,
#                             "y": 2.4841
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 278,
#                             "length": 10
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Amend Monitoring Order",
#                     "polygon": [
#                         {
#                             "x": 1.3283,
#                             "y": 2.5957
#                         },
#                         {
#                             "x": 3.1484,
#                             "y": 2.5957
#                         },
#                         {
#                             "x": 3.1484,
#                             "y": 2.7579
#                         },
#                         {
#                             "x": 1.3283,
#                             "y": 2.7528
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 289,
#                             "length": 22
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Conditions (Curfew)",
#                     "polygon": [
#                         {
#                             "x": 3.701,
#                             "y": 2.5906
#                         },
#                         {
#                             "x": 5.0496,
#                             "y": 2.5855
#                         },
#                         {
#                             "x": 5.0496,
#                             "y": 2.7579
#                         },
#                         {
#                             "x": 3.701,
#                             "y": 2.7579
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 312,
#                             "length": 19
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Terminate Monitoring Order",
#                     "polygon": [
#                         {
#                             "x": 1.3334,
#                             "y": 2.7883
#                         },
#                         {
#                             "x": 3.3461,
#                             "y": 2.7934
#                         },
#                         {
#                             "x": 3.3461,
#                             "y": 2.9607
#                         },
#                         {
#                             "x": 1.3334,
#                             "y": 2.9506
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 332,
#                             "length": 26
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Tick box if monitoring is to cease",
#                     "polygon": [
#                         {
#                             "x": 3.8886,
#                             "y": 2.7985
#                         },
#                         {
#                             "x": 6.1244,
#                             "y": 2.8035
#                         },
#                         {
#                             "x": 6.1244,
#                             "y": 2.9708
#                         },
#                         {
#                             "x": 3.8886,
#                             "y": 2.9607
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 372,
#                             "length": 34
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Withdraw Monitoring Order",
#                     "polygon": [
#                         {
#                             "x": 1.3232,
#                             "y": 3.0063
#                         },
#                         {
#                             "x": 3.3157,
#                             "y": 3.0114
#                         },
#                         {
#                             "x": 3.3106,
#                             "y": 3.1787
#                         },
#                         {
#                             "x": 1.3232,
#                             "y": 3.1686
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 407,
#                             "length": 25
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Tick box if Monitoring Order to be withdrawn",
#                     "polygon": [
#                         {
#                             "x": 3.8886,
#                             "y": 3.0114
#                         },
#                         {
#                             "x": 6.9001,
#                             "y": 3.0114
#                         },
#                         {
#                             "x": 6.9001,
#                             "y": 3.1888
#                         },
#                         {
#                             "x": 3.8886,
#                             "y": 3.1888
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 446,
#                             "length": 44
#                         }
#                     ]
#                 },
#                 {
#                     "content": "*= Mandatory Field",
#                     "polygon": [
#                         {
#                             "x": 1.2624,
#                             "y": 3.3967
#                         },
#                         {
#                             "x": 2.5096,
#                             "y": 3.4018
#                         },
#                         {
#                             "x": 2.5096,
#                             "y": 3.5741
#                         },
#                         {
#                             "x": 1.2624,
#                             "y": 3.5741
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 491,
#                             "length": 18
#                         }
#                     ]
#                 },
#                 {
#                     "content": "'HO Reference Number'*",
#                     "polygon": [
#                         {
#                             "x": 1.3232,
#                             "y": 3.7769
#                         },
#                         {
#                             "x": 3.123,
#                             "y": 3.7718
#                         },
#                         {
#                             "x": 3.123,
#                             "y": 3.9239
#                         },
#                         {
#                             "x": 1.3232,
#                             "y": 3.929
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 510,
#                             "length": 22
#                         }
#                     ]
#                 },
#                 {
#                     "content": "11111111",
#                     "polygon": [
#                         {
#                             "x": 4.2029,
#                             "y": 3.782
#                         },
#                         {
#                             "x": 4.8874,
#                             "y": 3.782
#                         },
#                         {
#                             "x": 4.8823,
#                             "y": 3.9239
#                         },
#                         {
#                             "x": 4.2029,
#                             "y": 3.9189
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 533,
#                             "length": 8
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Compliance and Enforcement Person",
#                     "polygon": [
#                         {
#                             "x": 1.3334,
#                             "y": 3.9746
#                         },
#                         {
#                             "x": 4.0559,
#                             "y": 3.9746
#                         },
#                         {
#                             "x": 4.0559,
#                             "y": 4.1318
#                         },
#                         {
#                             "x": 1.3334,
#                             "y": 4.1369
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 542,
#                             "length": 33
#                         }
#                     ]
#                 },
#                 {
#                     "content": "22222222",
#                     "polygon": [
#                         {
#                             "x": 4.1928,
#                             "y": 3.9797
#                         },
#                         {
#                             "x": 4.8874,
#                             "y": 3.9848
#                         },
#                         {
#                             "x": 4.8874,
#                             "y": 4.1166
#                         },
#                         {
#                             "x": 4.1928,
#                             "y": 4.1115
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 576,
#                             "length": 8
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Reference Number* (CEPR)",
#                     "polygon": [
#                         {
#                             "x": 1.3283,
#                             "y": 4.147
#                         },
#                         {
#                             "x": 3.2954,
#                             "y": 4.147
#                         },
#                         {
#                             "x": 3.2954,
#                             "y": 4.3092
#                         },
#                         {
#                             "x": 1.3283,
#                             "y": 4.3092
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 585,
#                             "length": 24
#                         }
#                     ]
#                 },
#                 {
#                     "content": "PERSON DETAILS",
#                     "polygon": [
#                         {
#                             "x": 1.3232,
#                             "y": 4.6895
#                         },
#                         {
#                             "x": 2.6718,
#                             "y": 4.6895
#                         },
#                         {
#                             "x": 2.6718,
#                             "y": 4.8618
#                         },
#                         {
#                             "x": 1.3232,
#                             "y": 4.8618
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 610,
#                             "length": 14
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Family name*",
#                     "polygon": [
#                         {
#                             "x": 1.3232,
#                             "y": 4.8821
#                         },
#                         {
#                             "x": 2.2561,
#                             "y": 4.8821
#                         },
#                         {
#                             "x": 2.2561,
#                             "y": 5.0393
#                         },
#                         {
#                             "x": 1.3232,
#                             "y": 5.0443
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 625,
#                             "length": 12
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Tom Test",
#                     "polygon": [
#                         {
#                             "x": 4.1928,
#                             "y": 4.877
#                         },
#                         {
#                             "x": 4.8721,
#                             "y": 4.877
#                         },
#                         {
#                             "x": 4.8721,
#                             "y": 5.0494
#                         },
#                         {
#                             "x": 4.1928,
#                             "y": 5.0494
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 638,
#                             "length": 8
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Given name*",
#                     "polygon": [
#                         {
#                             "x": 1.3232,
#                             "y": 5.0697
#                         },
#                         {
#                             "x": 2.2054,
#                             "y": 5.0697
#                         },
#                         {
#                             "x": 2.2105,
#                             "y": 5.2167
#                         },
#                         {
#                             "x": 1.3232,
#                             "y": 5.2167
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 647,
#                             "length": 11
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Tome",
#                     "polygon": [
#                         {
#                             "x": 4.1979,
#                             "y": 5.0798
#                         },
#                         {
#                             "x": 4.5984,
#                             "y": 5.0798
#                         },
#                         {
#                             "x": 4.5984,
#                             "y": 5.2116
#                         },
#                         {
#                             "x": 4.1979,
#                             "y": 5.2066
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 659,
#                             "length": 4
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Date of birth*",
#                     "polygon": [
#                         {
#                             "x": 1.3131,
#                             "y": 5.2522
#                         },
#                         {
#                             "x": 2.2155,
#                             "y": 5.2522
#                         },
#                         {
#                             "x": 2.2155,
#                             "y": 5.3992
#                         },
#                         {
#                             "x": 1.3131,
#                             "y": 5.3992
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 664,
#                             "length": 14
#                         }
#                     ]
#                 },
#                 {
#                     "content": "15/01/1989",
#                     "polygon": [
#                         {
#                             "x": 4.208,
#                             "y": 5.2573
#                         },
#                         {
#                             "x": 4.9634,
#                             "y": 5.2573
#                         },
#                         {
#                             "x": 4.9634,
#                             "y": 5.3992
#                         },
#                         {
#                             "x": 4.208,
#                             "y": 5.3941
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 679,
#                             "length": 10
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Gender*",
#                     "polygon": [
#                         {
#                             "x": 1.3182,
#                             "y": 5.4347
#                         },
#                         {
#                             "x": 1.9063,
#                             "y": 5.4347
#                         },
#                         {
#                             "x": 1.9063,
#                             "y": 5.5817
#                         },
#                         {
#                             "x": 1.3182,
#                             "y": 5.5817
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 690,
#                             "length": 7
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Male",
#                     "polygon": [
#                         {
#                             "x": 4.1877,
#                             "y": 5.4246
#                         },
#                         {
#                             "x": 4.5426,
#                             "y": 5.4296
#                         },
#                         {
#                             "x": 4.5426,
#                             "y": 5.5919
#                         },
#                         {
#                             "x": 4.1826,
#                             "y": 5.5868
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 698,
#                             "length": 4
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Person photo identification*",
#                     "polygon": [
#                         {
#                             "x": 1.3182,
#                             "y": 5.967
#                         },
#                         {
#                             "x": 3.1889,
#                             "y": 5.9569
#                         },
#                         {
#                             "x": 3.194,
#                             "y": 6.1293
#                         },
#                         {
#                             "x": 1.3182,
#                             "y": 6.1343
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 703,
#                             "length": 28
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Nationality*",
#                     "polygon": [
#                         {
#                             "x": 1.308,
#                             "y": 7.1483
#                         },
#                         {
#                             "x": 2.1091,
#                             "y": 7.1483
#                         },
#                         {
#                             "x": 2.1091,
#                             "y": 7.3156
#                         },
#                         {
#                             "x": 1.308,
#                             "y": 7.3105
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 732,
#                             "length": 12
#                         }
#                     ]
#                 },
#                 {
#                     "content": "British",
#                     "polygon": [
#                         {
#                             "x": 4.1928,
#                             "y": 7.1584
#                         },
#                         {
#                             "x": 4.644,
#                             "y": 7.1584
#                         },
#                         {
#                             "x": 4.644,
#                             "y": 7.2953
#                         },
#                         {
#                             "x": 4.1928,
#                             "y": 7.2902
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 745,
#                             "length": 7
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Registered address*",
#                     "polygon": [
#                         {
#                             "x": 1.3182,
#                             "y": 7.3308
#                         },
#                         {
#                             "x": 2.7124,
#                             "y": 7.3308
#                         },
#                         {
#                             "x": 2.7124,
#                             "y": 7.4981
#                         },
#                         {
#                             "x": 1.3182,
#                             "y": 7.5031
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 753,
#                             "length": 19
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Postcode*",
#                     "polygon": [
#                         {
#                             "x": 1.3232,
#                             "y": 7.858
#                         },
#                         {
#                             "x": 2.0178,
#                             "y": 7.858
#                         },
#                         {
#                             "x": 2.0229,
#                             "y": 8.0101
#                         },
#                         {
#                             "x": 1.3232,
#                             "y": 8.0152
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 773,
#                             "length": 9
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Lord's Cricket Ground",
#                     "polygon": [
#                         {
#                             "x": 4.1979,
#                             "y": 7.3308
#                         },
#                         {
#                             "x": 5.6935,
#                             "y": 7.3308
#                         },
#                         {
#                             "x": 5.6935,
#                             "y": 7.4829
#                         },
#                         {
#                             "x": 4.1979,
#                             "y": 7.4829
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 783,
#                             "length": 21
#                         }
#                     ]
#                 },
#                 {
#                     "content": "St John's Wood Rd,",
#                     "polygon": [
#                         {
#                             "x": 4.1928,
#                             "y": 7.5082
#                         },
#                         {
#                             "x": 5.5464,
#                             "y": 7.5082
#                         },
#                         {
#                             "x": 5.5464,
#                             "y": 7.6603
#                         },
#                         {
#                             "x": 4.1928,
#                             "y": 7.6603
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 805,
#                             "length": 18
#                         }
#                     ]
#                 },
#                 {
#                     "content": "London NW8 8QN",
#                     "polygon": [
#                         {
#                             "x": 4.1979,
#                             "y": 7.6806
#                         },
#                         {
#                             "x": 5.4603,
#                             "y": 7.6806
#                         },
#                         {
#                             "x": 5.4603,
#                             "y": 7.8377
#                         },
#                         {
#                             "x": 4.1979,
#                             "y": 7.8377
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 824,
#                             "length": 14
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Mobile phone number",
#                     "polygon": [
#                         {
#                             "x": 1.308,
#                             "y": 8.2129
#                         },
#                         {
#                             "x": 2.8188,
#                             "y": 8.2129
#                         },
#                         {
#                             "x": 2.8188,
#                             "y": 8.3802
#                         },
#                         {
#                             "x": 1.308,
#                             "y": 8.3802
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 839,
#                             "length": 19
#                         }
#                     ]
#                 },
#                 {
#                     "content": "07111 223111",
#                     "polygon": [
#                         {
#                             "x": 4.1928,
#                             "y": 8.218
#                         },
#                         {
#                             "x": 5.1713,
#                             "y": 8.218
#                         },
#                         {
#                             "x": 5.1713,
#                             "y": 8.3701
#                         },
#                         {
#                             "x": 4.1928,
#                             "y": 8.365
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 859,
#                             "length": 12
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Email address",
#                     "polygon": [
#                         {
#                             "x": 1.3131,
#                             "y": 8.4005
#                         },
#                         {
#                             "x": 2.3068,
#                             "y": 8.4005
#                         },
#                         {
#                             "x": 2.3017,
#                             "y": 8.5576
#                         },
#                         {
#                             "x": 1.3131,
#                             "y": 8.5576
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 872,
#                             "length": 13
#                         }
#                     ]
#                 },
#                 {
#                     "content": "tome@example.com",
#                     "polygon": [
#                         {
#                             "x": 4.1928,
#                             "y": 8.4005
#                         },
#                         {
#                             "x": 5.6174,
#                             "y": 8.4055
#                         },
#                         {
#                             "x": 5.6174,
#                             "y": 8.5576
#                         },
#                         {
#                             "x": 4.1928,
#                             "y": 8.5526
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 886,
#                             "length": 16
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Select primary language spoken",
#                     "polygon": [
#                         {
#                             "x": 1.3131,
#                             "y": 8.5779
#                         },
#                         {
#                             "x": 3.5185,
#                             "y": 8.583
#                         },
#                         {
#                             "x": 3.5185,
#                             "y": 8.7553
#                         },
#                         {
#                             "x": 1.3131,
#                             "y": 8.7503
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 903,
#                             "length": 30
#                         }
#                     ]
#                 },
#                 {
#                     "content": "English",
#                     "polygon": [
#                         {
#                             "x": 4.1928,
#                             "y": 8.583
#                         },
#                         {
#                             "x": 4.7251,
#                             "y": 8.588
#                         },
#                         {
#                             "x": 4.72,
#                             "y": 8.7452
#                         },
#                         {
#                             "x": 4.1928,
#                             "y": 8.7401
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 934,
#                             "length": 7
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Enter primary language spoken if 'other'",
#                     "polygon": [
#                         {
#                             "x": 1.3131,
#                             "y": 8.7655
#                         },
#                         {
#                             "x": 4.0305,
#                             "y": 8.7655
#                         },
#                         {
#                             "x": 4.0305,
#                             "y": 8.9328
#                         },
#                         {
#                             "x": 1.3131,
#                             "y": 8.9379
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 942,
#                             "length": 40
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Enter language here",
#                     "polygon": [
#                         {
#                             "x": 4.1979,
#                             "y": 8.7756
#                         },
#                         {
#                             "x": 5.734,
#                             "y": 8.7756
#                         },
#                         {
#                             "x": 5.734,
#                             "y": 8.9429
#                         },
#                         {
#                             "x": 4.1979,
#                             "y": 8.948
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 983,
#                             "length": 19
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Distinguishing marks",
#                     "polygon": [
#                         {
#                             "x": 1.3182,
#                             "y": 8.9581
#                         },
#                         {
#                             "x": 2.7479,
#                             "y": 8.9581
#                         },
#                         {
#                             "x": 2.7479,
#                             "y": 9.1305
#                         },
#                         {
#                             "x": 1.3182,
#                             "y": 9.1305
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 1003,
#                             "length": 20
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Yes",
#                     "polygon": [
#                         {
#                             "x": 4.3449,
#                             "y": 8.9886
#                         },
#                         {
#                             "x": 4.6541,
#                             "y": 8.9936
#                         },
#                         {
#                             "x": 4.6541,
#                             "y": 9.1102
#                         },
#                         {
#                             "x": 4.3449,
#                             "y": 9.1102
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 1037,
#                             "length": 3
#                         }
#                     ]
#                 },
#                 {
#                     "content": "No",
#                     "polygon": [
#                         {
#                             "x": 4.8417,
#                             "y": 8.9936
#                         },
#                         {
#                             "x": 5.0597,
#                             "y": 8.9936
#                         },
#                         {
#                             "x": 5.0597,
#                             "y": 9.1102
#                         },
#                         {
#                             "x": 4.8417,
#                             "y": 9.1102
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 1052,
#                             "length": 2
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Record any distinguishing marks here",
#                     "polygon": [
#                         {
#                             "x": 4.2029,
#                             "y": 9.1609
#                         },
#                         {
#                             "x": 6.7835,
#                             "y": 9.1559
#                         },
#                         {
#                             "x": 6.7835,
#                             "y": 9.3232
#                         },
#                         {
#                             "x": 4.2029,
#                             "y": 9.3282
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 1055,
#                             "length": 36
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Are there any known vulnerabilities",
#                     "polygon": [
#                         {
# ...
#                     "column_index": 0,
#                     "row_span": 1,
#                     "column_span": 1,
#                     "content": "If 'yes', enter address where HMU is to be installed",
#                     "bounding_regions": [
#                         {
#                             "page_number": 2,
#                             "polygon": [
#                                 {
#                                     "x": 1.2461,
#                                     "y": 9.1043
#                                 },
#                                 {
#                                     "x": 4.1026,
#                                     "y": 9.1043
#                                 },
#                                 {
#                                     "x": 4.1026,
#                                     "y": 9.6603
#                                 },
#                                 {
#                                     "x": 1.2461,
#                                     "y": 9.6603
#                                 }
#                             ]
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 2723,
#                             "length": 52
#                         }
#                     ]
#                 },
#                 {
#                     "kind": "content",
#                     "row_index": 11,
#                     "column_index": 1,
#                     "row_span": 1,
#                     "column_span": 1,
#                     "content": "Click here to enter full address and postcode",
#                     "bounding_regions": [
#                         {
#                             "page_number": 2,
#                             "polygon": [
#                                 {
#                                     "x": 4.1026,
#                                     "y": 9.1043
#                                 },
#                                 {
#                                     "x": 7.0129,
#                                     "y": 9.1043
#                                 },
#                                 {
#                                     "x": 7.0129,
#                                     "y": 9.6603
#                                 },
#                                 {
#                                     "x": 4.1026,
#                                     "y": 9.6603
#                                 }
#                             ]
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 2776,
#                             "length": 45
#                         }
#                     ]
#                 },
#                 {
#                     "kind": "content",
#                     "row_index": 12,
#                     "column_index": 0,
#                     "row_span": 1,
#                     "column_span": 1,
#                     "content": "Date HMU to be installed dd/mm/yyyy",
#                     "bounding_regions": [
#                         {
#                             "page_number": 2,
#                             "polygon": [
#                                 {
#                                     "x": 1.2461,
#                                     "y": 9.6603
#                                 },
#                                 {
#                                     "x": 4.1026,
#                                     "y": 9.6603
#                                 },
#                                 {
#                                     "x": 4.1026,
#                                     "y": 9.8396
#                                 },
#                                 {
#                                     "x": 1.2461,
#                                     "y": 9.8396
#                                 }
#                             ]
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 2822,
#                             "length": 35
#                         }
#                     ]
#                 },
#                 {
#                     "kind": "content",
#                     "row_index": 12,
#                     "column_index": 1,
#                     "row_span": 1,
#                     "column_span": 1,
#                     "content": "Select date from calendar.",
#                     "bounding_regions": [
#                         {
#                             "page_number": 2,
#                             "polygon": [
#                                 {
#                                     "x": 4.1026,
#                                     "y": 9.6603
#                                 },
#                                 {
#                                     "x": 7.0129,
#                                     "y": 9.6603
#                                 },
#                                 {
#                                     "x": 7.0129,
#                                     "y": 9.8396
#                                 },
#                                 {
#                                     "x": 4.1026,
#                                     "y": 9.8396
#                                 }
#                             ]
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 2858,
#                             "length": 26
#                         }
#                     ]
#                 },
#                 {
#                     "kind": "content",
#                     "row_index": 13,
#                     "column_index": 0,
#                     "row_span": 1,
#                     "column_span": 1,
#                     "content": "Time HMU to be installed (24 hr clock)",
#                     "bounding_regions": [
#                         {
#                             "page_number": 2,
#                             "polygon": [
#                                 {
#                                     "x": 1.2461,
#                                     "y": 9.8396
#                                 },
#                                 {
#                                     "x": 4.1026,
#                                     "y": 9.8396
#                                 },
#                                 {
#                                     "x": 4.1026,
#                                     "y": 10.0189
#                                 },
#                                 {
#                                     "x": 1.2461,
#                                     "y": 10.0189
#                                 }
#                             ]
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 2885,
#                             "length": 38
#                         }
#                     ]
#                 },
#                 {
#                     "kind": "content",
#                     "row_index": 13,
#                     "column_index": 1,
#                     "row_span": 1,
#                     "column_span": 1,
#                     "content": "Click here to enter time (hh:mm)",
#                     "bounding_regions": [
#                         {
#                             "page_number": 2,
#                             "polygon": [
#                                 {
#                                     "x": 4.1026,
#                                     "y": 9.8396
#                                 },
#                                 {
#                                     "x": 7.0129,
#                                     "y": 9.8396
#                                 },
#                                 {
#                                     "x": 7.0129,
#                                     "y": 10.0189
#                                 },
#                                 {
#                                     "x": 4.1026,
#                                     "y": 10.0189
#                                 }
#                             ]
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 2924,
#                             "length": 32
#                         }
#                     ]
#                 }
#             ],
#             "bounding_regions": [
#                 {
#                     "page_number": 2,
#                     "polygon": [
#                         {
#                             "x": 1.2368,
#                             "y": 5.7822
#                         },
#                         {
#                             "x": 7.0235,
#                             "y": 5.7888
#                         },
#                         {
#                             "x": 7.0162,
#                             "y": 10.0281
#                         },
#                         {
#                             "x": 1.2283,
#                             "y": 10.022
#                         }
#                     ]
#                 }
#             ],
#             "spans": [
#                 {
#                     "offset": 1968,
#                     "length": 39
#                 },
#                 {
#                     "offset": 2057,
#                     "length": 26
#                 },
#                 {
#                     "offset": 2019,
#                     "length": 37
#                 },
#                 {
#                     "offset": 2084,
#                     "length": 872
#                 }
#             ]
#         }
#     ],
#     "key_value_pairs": [],
#     "styles": [
#         {
#             "is_handwritten": true,
#             "similar_font_family": null,
#             "font_style": null,
#             "font_weight": null,
#             "color": null,
#             "background_color": null,
#             "spans": [
#                 {
#                     "offset": 1227,
#                     "length": 1
#                 }
#             ],
#             "confidence": 0.7
#         },
#         {
#             "is_handwritten": true,
#             "similar_font_family": null,
#             "font_style": null,
#             "font_weight": null,
#             "color": null,
#             "background_color": null,
#             "spans": [
#                 {
#                     "offset": 1783,
#                     "length": 4
#                 }
#             ],
#             "confidence": 0.1
#         }
#     ],
#     "documents": [
#         {
#             "doc_type": "ELMModel:ELMModel",
#             "bounding_regions": [
#                 {
#                     "page_number": 1,
#                     "polygon": [
#                         {
#                             "x": 0.0,
#                             "y": 0.0
#                         },
#                         {
#                             "x": 8.2639,
#                             "y": 0.0
#                         },
#                         {
#                             "x": 8.2639,
#                             "y": 11.6806
#                         },
#                         {
#                             "x": 0.0,
#                             "y": 11.6806
#                         }
#                     ]
#                 },
#                 {
#                     "page_number": 2,
#                     "polygon": [
#                         {
#                             "x": 0.0,
#                             "y": 0.0
#                         },
#                         {
#                             "x": 8.2639,
#                             "y": 0.0
#                         },
#                         {
#                             "x": 8.2639,
#                             "y": 11.6806
#                         },
#                         {
#                             "x": 0.0,
#                             "y": 11.6806
#                         }
#                     ]
#                 }
#             ],
#             "spans": [
#                 {
#                     "offset": 0,
#                     "length": 2956
#                 }
#             ],
#             "fields": {
#                 "Notification": {
#                     "value_type": "string",
#                     "value": null,
#                     "content": null,
#                     "bounding_regions": [],
#                     "spans": [],
#                     "confidence": 0.995
#                 },
#                 "DOB": {
#                     "value_type": "string",
#                     "value": null,
#                     "content": null,
#                     "bounding_regions": [],
#                     "spans": [],
#                     "confidence": 0.987
#                 },
#                 "DateOfOrder": {
#                     "value_type": "string",
#                     "value": null,
#                     "content": null,
#                     "bounding_regions": [],
#                     "spans": [],
#                     "confidence": 0.605
#                 },
#                 "DefendantName": {
#                     "value_type": "string",
#                     "value": null,
#                     "content": null,
#                     "bounding_regions": [],
#                     "spans": [],
#                     "confidence": 0.749
#                 },
#                 "DefendantAddress": {
#                     "value_type": "string",
#                     "value": null,
#                     "content": null,
#                     "bounding_regions": [],
#                     "spans": [],
#                     "confidence": 0.995
#                 },
#                 "PNCID": {
#                     "value_type": "string",
#                     "value": null,
#                     "content": null,
#                     "bounding_regions": [],
#                     "spans": [],
#                     "confidence": 0.468
#                 },
#                 "DestinationID": {
#                     "value_type": "string",
#                     "value": null,
#                     "content": null,
#                     "bounding_regions": [],
#                     "spans": [],
#                     "confidence": 0.937
#                 },
#                 "Court": {
#                     "value_type": "string",
#                     "value": null,
#                     "content": null,
#                     "bounding_regions": [],
#                     "spans": [],
#                     "confidence": 0.919
#                 },
#                 "EMHeading": {
#                     "value_type": "string",
#                     "value": null,
#                     "content": null,
#                     "bounding_regions": [],
#                     "spans": [],
#                     "confidence": 0.544
#                 },
#                 "Gender": {
#                     "value_type": "string",
#                     "value": null,
#                     "content": null,
#                     "bounding_regions": [],
#                     "spans": [],
#                     "confidence": 0.995
#                 },
#                 "CaseNumber": {
#                     "value_type": "string",
#                     "value": null,
#                     "content": null,
#                     "bounding_regions": [],
#                     "spans": [],
#                     "confidence": 0.954
#                 },
#                 "MobileNumber": {
#                     "value_type": "string",
#                     "value": null,
#                     "content": null,
#                     "bounding_regions": [],
#                     "spans": [],
#                     "confidence": 0.671
#                 },
#                 "CourtContact": {
#                     "value_type": "string",
#                     "value": null,
#                     "content": null,
#                     "bounding_regions": [],
#                     "spans": [],
#                     "confidence": 0.974
#                 },
#                 "URN": {
#                     "value_type": "string",
#                     "value": null,
#                     "content": null,
#                     "bounding_regions": [],
#                     "spans": [],
#                     "confidence": 0.961
#                 }
#             },
#             "confidence": 0.004
#         }
#     ]
# }
# --------------JSON Response from Model Ends---------------------
